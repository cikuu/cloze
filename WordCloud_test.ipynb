# %%
# 从pyecharts模块 导入WordCloud功能
# 使用nltk的word_tokenize功能进行分词
# 使用nltk的FreqDist功能进行词频统计
# 从nltk.corpus中导入stopwords库进行停用词过滤
# 从nltk.stem中导入WordNetLemmatizer进行词形还原
from pyecharts.charts import WordCloud
from nltk import *
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer  

# 自定义函数获得清洗后的文本词表并统计词频
def word_list(res):
    # 大小写归一
    text = res.lower()
    # 对文本进行分词
    text_list=word_tokenize(text)
    # 去掉标点符号
    punctuation = [',', '.', ':', ';', '?', '(', ')', '[', ']', '&', '!', '*', '@', '#', '$', '%']
    text_list = [word for word in text_list if word not in punctuation]
    # 去掉停用词
    stop_words = set(stopwords.words('english'))
    text_list = [word for word in text_list if word not in stop_words]
    # 还原词形
    new_list=[]
    wnt = WordNetLemmatizer()  
    for word in text_list:
        word = wnt.lemmatize(word)
        new_list.append(word)
    # 我们对清洗后的词表进行词频统计
    output = FreqDist(new_list)
    # 使用pyecharts中WordCloud绘制词云图时，其分析对象可以是列表数据
    # 这里返回数据就需要将得到的FreqDist对象转化为元组列表
    # 对待FreqDist对象，我们可以使用字典的操作方法
    return list(output.items())

# %% [markdown]
# 调用获取词频表自定义函数word_list，对一篇文章进行词云图绘制。

# %%
# 读取文本文件 获得作文内容
f = open('test.txt')
content = f.read()
# 调用自定义函数获得词表
freq = word_list(content)

# 生成词云图
cloud = WordCloud()
cloud.add('',freq, shape='circle')
cloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="7686c463b1034f6c8c3c01504cdd3960" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_7686c463b1034f6c8c3c01504cdd3960 = echarts.init(
#                     document.getElementById('7686c463b1034f6c8c3c01504cdd3960'), 'white', {renderer: 'canvas'});
#                 var option_7686c463b1034f6c8c3c01504cdd3960 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "drizzling",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,133,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "rain",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,104,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "fall",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,16,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "like",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,61,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "tear",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,53,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "mourning",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,1,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "day",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,138,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "mourner",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,159,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "'s",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,86,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "heart",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,32,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "going",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,130,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "break",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,120,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "way",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,126,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "wine",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,95,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "shop",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,46,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "found",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,56,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "drown",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,65,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "sad",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,129,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hour",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,86,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "cowherd",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,110,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "point",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,73,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "cot",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,44,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "'mid",
#                     "value": 1,
#                     "textStyle": {

# %% [markdown]
# 我们也可以对多篇文章进行分析统计。

# %%
# 使用pandas模块read_excel功能读取excel文件
from pandas import *

# 读取文本文件 获得作文内容
# 首先将文件上传，根据文件路径进行读取
path = "translation01.xlsx"
data = read_excel(path)
# 需要对第二列的文本进行分析
alltext = data.iloc[:,1]
transcontent = ''
for text in alltext:
    transcontent = transcontent+text

# 调用word_list自定义函数获得词表及词频
transfreq = word_list(transcontent)

# 生成词云图
cloud = WordCloud()
cloud.add('',transfreq, shape='circle')
cloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="7eaf52f3f38d4541a3778a2ed71e59fe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_7eaf52f3f38d4541a3778a2ed71e59fe = echarts.init(
#                     document.getElementById('7eaf52f3f38d4541a3778a2ed71e59fe'), 'white', {renderer: 'canvas'});
#                 var option_7eaf52f3f38d4541a3778a2ed71e59fe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "living",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,15,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "mobile",
#                     "value": 36,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,42,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "internet",
#                     "value": 59,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,150,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "age",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,83,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "college",
#                     "value": 40,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,117,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "student",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,79,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "separated",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,104,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "now.living",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,9,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "hardly",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,6,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "without",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,66,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "network.living",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,104,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "era",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,129,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "inseparable",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,128,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "internet.living",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,157,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "undergraduate",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,49,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "ca",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,48,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "n't",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,60,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "maintain",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,134,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "away",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,100,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "network",
#                     "value": 6,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,130,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "anymore",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,159,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "interent",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,128,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "become",

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
